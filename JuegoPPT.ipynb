# %%
import math
import random

# %%
import random

def play():
    user = input(" ¿Qué vas a usar? 'piedra','papel','tijeras' ")
    computer = random.choice (['piedra', 'papel', 'tijeras'])
    
    if user == computer:
        return 'Es un Empate'
    
    if is_win(user, computer):
        return '¡Ganaste!'
    return '¡Perdiste!'

def is_win(player, opponent):
    if (player == 'piedra' and opponent == 'tijeras') or (player == 'tijeras' and opponent == 'papel') \
        or (player == 'papel' and opponent == 'tijeras'):
        return True
    
print(play())
# Out:
# ¡Perdiste!

# %%
for i in range(5):
    print(f"ronda {i+1}:")
    resultado = play()
    print(resultado)
    print
# Out:
# ronda 1:
# ¡Ganaste!
# ronda 2:
# ¡Perdiste!
# ronda 3:
# ¡Perdiste!
# ronda 4:
# Es un Empate
# ronda 5:
# ¡Perdiste!

# %%
# !"#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
import random
chars = '!"#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz'
password = ''
lengthPW = int(input('Que longitud quieres para tu pw'))
for _ in range(lengthPW):
    password += random.choice(chars)
print(password)
# Out:
# w%,.TE#$#Sjh5-90"mkF*rh*y-nw&It*MjTIF@gp#n+!Q4iW7(+xl6+tB4$S0p4Ng&bJ&8I5M5h&uXSlRwhi&iy7e

# %%
# !"#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
import random
random.seed(1234)
chars = '!"#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz'
password = ''
lengthPW = int(input('Que longitud quieres para tu pw'))
for _ in range(lengthPW):
    password += random.choice(chars)
print(password)
# Out:
# e0!-w%,.

# %%
contraseña = "Computadora"
contador = 0
while True:
    contraseña_imput = input("Introduzca una Contraseña")
    contador +=1
    
    if contador > 3:
        print("Haz sobrepasado los intetos")
        
    elif contraseña_imput == "Computadora":
        print("contraseña correcta")
        break 
    
    else:
        print("Contraseña incorrecta , Introduzca una contraseña correcta")
# Out:
# Contraseña incorrecta , NO SE ACUERDADA JAJAJA

# %%
contraseña = "Angel123"
contador = 0
while True:
    contraseña_imput = input("Introduzca una Contraseña")
    contador +=1
    
    if contador >= 3:
        print("Haz sobrepasado los intetos")
        
    elif contraseña_imput == "Angel123":
        print("contraseña correcta")
        break 
    
    else:
        print("Contraseña incorrecta , No se acuerda jajaja")
# Out:
# Contraseña incorrecta , No se acuerda jajaja
# Contraseña incorrecta , No se acuerda jajaja
# Haz sobrepasado los intetos
